# %% [markdown]
# # Parallelization Lab
#
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.
#
# ### Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
# your code here

response = requests.get(url)

if response.status_code == 200:
    content = response.text
    print("Content retrieved successfully.")
else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")
# Out:
# Content retrieved successfully.

# %% [markdown]
# ### Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup

# %%
# your code here

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Step 3: Use list comprehensions with conditions to clean the link list.
#
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with *http* while relative links begin with a forward slash (/) and point to an internal page within the *wikipedia.org* domain. Clean the respective types of URLs as follows.
#
# - Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
# - Relative Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
# - Combine the list of absolute and relative links and ensure there are no duplicates.

# %%
domain = 'http://wikipedia.org'

# %%
# your code here

# Absolute links

# Get the request and clean string
absol_links = soup.find_all("a", attrs={'class':'external text'})
list = [str(link) for link in absol_links]
list = [link.replace('<a class="external text" href=', '') for link in list]
list = [link.split('"') for link in list]

# Create link list, delete the ones with "?"
list2 = [(i[1]) for i in list] 
absol_list = [item for item in list2 if not "?" in item]

# %%
# Relative links

domain = 'http://wikipedia.org'
relat_links = soup.find_all("a",attrs={'class':'mw-redirect'})

# Get the request and clean string
list = [str(link) for link in relat_links]
list = [link.replace('<a class="mw-redirect" href=', '') for link in list]
list = [link.split('"') for link in list]

# Create link list, delete the ones with "?"
list2 = [(domain+i[1]) for i in list] 
relat_list = [item for item in list2 if not "?" in item]

# %%
# Convert to set to erase repeated and then again into list
final_set = set(absol_list+relat_list)
final_list = [item for item in final_set]
final_list2 = []

# Adding http where is missing
for item in final_list:
    if item[0]=="/":
        item = 'http:'+ item
        final_list2.append(item)
    else:
        final_list2.append(item)

final_list2
# Out:
# ['https://api.semanticscholar.org/CorpusID:9743327',
#  'http://wikipedia.org/wiki/Iterative',
#  'https://www.worldcat.org/issn/0360-0300',
#  'http://wikipedia.org/wiki/Data_(computing)',
#  'http://wikipedia.org/wiki/Scientific_computing',
#  'http://wikipedia.org/wiki/Problem-solving',
#  'https://medriscoll.com/post/4740157098/the-three-sexy-skills-of-data-geeks',
#  'https://www.researchgate.net/publication/256438799',
#  'https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/',
#  'https://pubmed.ncbi.nlm.nih.gov/19265007',
#  'https://www.worldcat.org/issn/0001-0782',
#  'http://wikipedia.org/wiki/Data_loading',
#  'http://wikipedia.org/wiki/Information_visualization',
#  'https://www.bostonglobe.com/business/2015/11/11/behind-scenes-sexiest-job-century/Kc1cvXIu31DfHhVmyRQeIJ/story.html',
#  'https://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  'https://www.worldcat.org/issn/0017-8012',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century',
#  'https://www.springer.com/book/9784431702085',
#  'http://wikipedia.org/wiki/ISBN_(identifier)',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  'http://priceonomics.com/whats-the-difference-between-data-science-and/',
#  'https://api.semanticscholar.org/CorpusID:6107147',
#  'http://wikipedia.org/wiki/Data_visualization',
#  'https://www.worldcat.org/issn/0036-8075',
#  'https://benfry.com/phd/dissertation/2.html',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  'https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  'http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'http://wikipedia.org/wiki/Interdisciplinary_field',
#  'http://wikipedia.org/wiki/Machine_learning_algorithms',
#  'http://wikipedia.org/wiki/Complex_systems',
#  'https://doi.org/10.1126%2Fscience.1170411',
#  'http://wikipedia.org/wiki/OCLC_(identifier)',
#  'https://doi.org/10.3390%2Fbdcc2020014',
#  'http://wikipedia.org/wiki/New_York_Times',
#  'http://wikipedia.org/wiki/Data_transformation',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  'https://www.nytimes.com/2013/04/14/education/edlife/universities-offer-courses-in-a-hot-new-field-data-science.html',
#  'http://wikipedia.org/wiki/ISSN_(identifier)',
#  'https://www.oreilly.com/library/view/doing-data-science/9781449363871/ch01.html',
#  'http://wikipedia.org/wiki/S2CID_(identifier)',
#  'https://static1.squarespace.com/static/5ff2adbe3fe4fe33db902812/t/6009dd9fa7bc363aa822d2c7/1611259312432/ISLR+Seventh+Printing.pdf',
#  'http://wikipedia.org/wiki/Structured_data',
#  'https://doi.org/10.1007%2F978-4-431-65950-1_3',
#  'https://doi.org/10.1145%2F3575663',
#  'https://hbr.org/2022/07/is-data-scientist-still-the-sexiest-job-of-the-21st-century',
#  'http://wikipedia.org/wiki/Boston_Globe',
#  'http://wikipedia.org/wiki/Statistical_analysis',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'https://doi.org/10.1145%2F3076253',
#  'http://wikipedia.org/wiki/Interdisciplinary',
#  'https://www2.isye.gatech.edu/~jeffwu/publications/fazhan.pdf',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  'http://wikipedia.org/wiki/Doi_(identifier)',
#  'http://wikipedia.org/wiki/Data_analyst',
#  'http://archive.nyu.edu/handle/2451/31553',
#  'http://wikipedia.org/wiki/Data_preprocessing',
#  'http://wikipedia.org/wiki/Phenomena',
#  'https://www.worldcat.org/oclc/489990740',
#  'http://wikipedia.org/wiki/Committee_on_Data_for_Science_and_Technology',
#  'https://flowingdata.com/2009/06/04/rise-of-the-data-scientist/',
#  'https://www.nsf.gov/pubs/2005/nsb0540/',
#  'https://pubmed.ncbi.nlm.nih.gov/23074866',
#  'https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/',
#  'http://wikipedia.org/wiki/Data_library',
#  'https://dstf.acm.org/DSTF_Final_Report.pdf',
#  'https://doi.org/10.3390%2Fmake1010015',
#  'https://api.semanticscholar.org/CorpusID:207595944',
#  'https://www.statisticsviews.com/article/nate-silver-what-i-need-from-statisticians/',
#  'https://www.sciencedirect.com/book/9780123814791/data-mining-concepts-and-techniques',
#  'https://api.semanticscholar.org/CorpusID:114558008',
#  'https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/',
#  'https://doi.org/10.1080%2F10618600.2017.1384734',
#  'https://doi.org/10.1145%2F2500499',
#  'https://www.stat.purdue.edu/~wsc/',
#  'http://wikipedia.org/wiki/Data_pre-processing',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  'http://wikipedia.org/wiki/Variable_(research)',
#  'http://wikipedia.org/wiki/Data_cleaning',
#  'http://wikipedia.org/wiki/Domain_expertise',
#  'https://www.researchgate.net/publication/354866394',
#  'http://wikipedia.org/wiki/PMID_(identifier)']

# %% [markdown]
# ### Step 4: Use the os library to create a folder called *wikipedia* and make that the current working directory.

# %%
import os

# %%
# your code here

# Create a folder called 'wikipedia'
folder_name = 'wikipedia'
os.makedirs(folder_name, exist_ok=True)

# Set the current working directory to the new folder
os.chdir(folder_name)

# Print the current working directory to verify the change
print(f"Current Working Directory: {os.getcwd()}")
# Out:
# Current Working Directory: /Users/amandine/Desktop/Ironhack/10_Week/lab-parallelization/your-code/wikipedia

# %% [markdown]
# ### Step 5: Write a function called index_page that accepts a link and does the following.
#
# - Tries to request the content of the page referenced by that link.
# - Slugifies the filename using the `slugify` function from the [python-slugify](https://pypi.org/project/python-slugify/) library and adds a .html file extension.
#     - If you don't already have the python-slugify library installed, you can pip install it as follows: `$ pip3 install python-slugify`.
#     - To import the slugify function, you would do the following: `from slugify import slugify`.
#     - You can then slugify a link as follows `slugify(link)`.
# - Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
# - If an exception occurs during the process above, just `pass`.

# %%
from slugify import slugify
import time

# %%
# your code here

def index_page(link):
    try:
        response = requests.get(link)
        soup = BeautifulSoup(response.content)
        file_name = slugify(link)+'.html'
        fp = open(file_name, 'w')
        fp.write(str(soup))
        fp.close()
        print('Link: ', link, 'done..')
    except:
#         print('This link: ', link, 'failed...')
        pass

# %% [markdown]
# ### Step 6: Sequentially loop through the list of links, running the index_page function each time.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# your code here

start_time = time.time()

# Assuming you have the list of cleaned_links from previous steps
for link in cleaned_links:
    index_page(link)

end_time = time.time()
execution_time = end_time - start_time

print(f"Total Execution Time: {execution_time:.2f} seconds")
# Out:
# Link:  https://eo.wikipedia.org/wiki/Datum-scienco done..
# Link:  http://wikipedia.org/wiki/Data_loading done..
# Link:  http://wikipedia.org/w/index.php?title=Special:DownloadAsPdf&page=Data_science&action=show-download-screen done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=2 done..
# Link:  http://wikipedia.org/wiki/Main_Page done..
# Link:  http://wikipedia.org/wiki/Database done..
# Link:  http://wikipedia.org/wiki/Boston_Globe done..
# Link:  http://wikipedia.org/wiki/Data_scraping done..
# Link:  http://wikipedia.org/wiki/Data_fusion done..
# Link:  http://wikipedia.org/wiki/Critical_thinking done..
# Link:  https://www.researchgate.net/publication/256438799 done..
# Link:  https://web.archive.org/web/20170320193019/https://books.google.com/books?id=oGs_AQAAIAAJ done..
# Link:  http://wikipedia.org/wiki/Data_farming done..
# Link:  http://wikipedia.org/wiki/Data_(computing) done..
# Link:  https://www.worldcat.org/issn/0001-0782 done..
# Link:  http://wikipedia.org/wiki/Phenomena done..
# Link:  https://id.wikipedia.org/wiki/Ilmu_data done..
# Link:  http://wikipedia.org/wiki/Business done..
# Link:  http://wikipedia.org/wiki/David_Donoho done..
# Link:  http://wikipedia.org/wiki/Data_storage done..
# Link:  http://wikipedia.org/wiki/Data_collection done..
# Link:  http://wikipedia.org/wiki/Graphic_design done..
# Link:  http://wikipedia.org/wiki/Ben_Fry done..
# Link:  http://wikipedia.org/wiki/File:PIA23792-1600x1200(1).jpg done..
# Link:  http://priceonomics.com/whats-the-difference-between-data-science-and/ done..
# Link:  http://wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Data+science done..
# Link:  https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/ done..
# Link:  http://wikipedia.org/wiki/Special:MyContributions done..
# Link:  http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext done..
# Link:  http://wikipedia.org/wiki/John_Tukey done..
# Link:  https://tr.wikipedia.org/wiki/Veri_bilimi done..
# Link:  http://wikipedia.org/wiki/Forbes done..
# Link:  http://wikipedia.org/wiki/Data_quality done..
# Link:  http://wikipedia.org/wiki/Special:Search done..
# Link:  http://wikipedia.org/wiki/Category:Articles_using_small_message_boxes done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=5 done..
# Link:  https://hbr.org/2022/07/is-data-scientist-still-the-sexiest-job-of-the-21st-century done..
# Link:  http://wikipedia.org/wiki/Information_science done..
# Link:  http://wikipedia.org/wiki/Big_data done..
# Link:  http://wikipedia.org/wiki/Wide-field_Infrared_Survey_Explorer done..
# Link:  http://wikipedia.org/wiki/Information_visualization done..
# Link:  http://wikipedia.org//foundation.wikimedia.org/wiki/Privacy_policy done..
# Link:  http://wikipedia.org//www.wikimediafoundation.org/ done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=6 done..
# Link:  http://archive.nyu.edu/handle/2451/31553 done..
# Link:  http://wikipedia.org/wiki/Data_set done..
# Link:  http://wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Data_science&id=1189437909&wpFormIdentifier=titleform done..
# Link:  http://wikipedia.org/wiki/Analysis done..
# Link:  http://wikipedia.org/wiki/Data_analysis done..
# Link:  http://wikipedia.org/wiki/Data_security done..
# Link:  http://wikipedia.org/wiki/Special:Random done..
# Link:  http://wikipedia.org/wiki/R_(programming_language) done..
# Link:  http://wikipedia.org/wiki/Scientific_method done..
# Link:  http://wikipedia.org/wiki/Nathan_Yau done..
# Link:  http://wikipedia.org/wiki/ISSN_(identifier) done..
# Link:  http://wikipedia.org/wiki/Data_warehouse done..
# Link:  https://it.wikipedia.org/wiki/Scienza_dei_dati done..
# Link:  https://de.wikipedia.org/wiki/Data_Science done..
# Link:  https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/ done..
# Link:  http://wikipedia.org/wiki/Montpellier_2_University done..
# Link:  http://wikipedia.org/wiki/Complex_systems done..
# Link:  http://wikipedia.org/wiki/Knowledge done..
# Link:  https://www.sciencedirect.com/book/9780123814791/data-mining-concepts-and-techniques done..
# Link:  http://wikipedia.org/wiki/Mathematics done..
# Link:  http://wikipedia.org/wiki/Variable_(research) done..
# Link:  http://wikipedia.org/wiki/Informatics done..
# Link:  http://wikipedia.org/wiki/Python_(programming_language) done..
# Link:  https://api.semanticscholar.org/CorpusID:9743327 done..
# Link:  https://et.wikipedia.org/wiki/Andmeteadus done..
# Link:  http://wikipedia.org/wiki/Special:RecentChangesLinked/Data_science done..
# Link:  http://wikipedia.org/wiki/Data_synchronization done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=3 done..
# Link:  http://wikipedia.org/wiki/Computer_programming done..
# Link:  https://pubmed.ncbi.nlm.nih.gov/19265007 done..
# Link:  https://commons.wikimedia.org/wiki/Category:Data_science done..
# Link:  http://wikipedia.org/wiki/Jim_Gray_(computer_scientist) done..
# Link:  http://wikipedia.org/wiki/S2CID_(identifier) done..
# Link:  http://wikipedia.org/wiki/Data_compression done..
# Link:  http://wikipedia.org/wiki/Data_format_management done..
# Link:  https://magazine.amstat.org/blog/2016/06/01/datascience-2/ done..
# Link:  http://wikipedia.org/wiki/Data_publishing done..
# Link:  http://wikipedia.org/wiki/Machine_learning_algorithms done..
# Link:  https://www.worldcat.org/issn/0017-8012 done..
# Link:  http://wikipedia.org/wiki/Data_loss done..
# Link:  https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia done..
# Link:  http://wikipedia.org/wiki/Interdisciplinary done..
# Link:  https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/ done..
# Link:  http://wikipedia.org/wiki/Comet_NEOWISE done..
# Link:  http://wikipedia.org/wiki/Algorithm done..
# Link:  https://api.semanticscholar.org/CorpusID:6107147 done..
# Link:  http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf done..
# Link:  https://simple.wikipedia.org/wiki/Data_science done..
# Link:  http://wikipedia.org/wiki/Data_reduction done..
# Link:  http://wikipedia.org/wiki/Wikipedia:About done..
# Link:  http://wikipedia.org/wiki/Help:Category done..
# Link:  https://nl.wikipedia.org/wiki/Datawetenschap done..
# Link:  http://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us done..
# Link:  http://wikipedia.org/wiki/Structured_data done..
# Link:  https://www.nytimes.com/2013/04/14/education/edlife/universities-offer-courses-in-a-hot-new-field-data-science.html done..
# Link:  http://wikipedia.org/wiki/William_S._Cleveland done..
# Link:  http://wikipedia.org/wiki/Special:EditPage/Template:Data done..
# Link:  http://wikipedia.org/wiki/Data_degradation done..
# Link:  http://wikipedia.org/wiki/Special:SpecialPages done..
# Link:  https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy done..
# Link:  http://wikipedia.org/wiki/Astronomical_survey done..
# Link:  http://wikipedia.org/wiki/Help:Contents done..
# Link:  https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext done..
# Link:  http://wikipedia.org/wiki/Data_philanthropy done..
# Link:  http://wikipedia.org/wiki/Data_augmentation done..
# Link:  http://wikipedia.org/wiki/Feature_engineering done..
# Link:  http://wikipedia.org/wiki/Data_management done..
# Link:  http://wikipedia.org/wiki/Basic_research done..
# Link:  http://wikipedia.org/wiki/Data_library done..
# Link:  https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement done..
# Link:  http://wikipedia.org/wiki/Space_telescope done..
# Link:  http://wikipedia.org/wiki/Information_privacy done..
# Link:  https://www.worldcat.org/oclc/489990740 done..
# Link:  http://wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata done..
# Link:  http://wikipedia.org/wiki/Help:Introduction done..
# Link:  http://wikipedia.org/wiki/DJ_Patil done..
# Link:  https://www.nsf.gov/pubs/2005/nsb0540/ done..
# Link:  http://wikipedia.org/wiki/American_Statistical_Association done..
# Link:  http://wikipedia.org/wiki/Data_steward done..
# Link:  http://wikipedia.org/wiki/Computational_science done..
# Link:  http://wikipedia.org/wiki/Category:Use_dmy_dates_from_August_2023 done..
# Link:  https://dstf.acm.org/DSTF_Final_Report.pdf done..
# Link:  http://wikipedia.org/wiki/Iterative done..
# Link:  http://wikipedia.org/wiki/Data_mining done..
# Link:  https://api.semanticscholar.org/CorpusID:207595944 done..
# Link:  http://wikipedia.org/wiki/Category:Information_science done..
# Link:  https://gl.wikipedia.org/wiki/Ciencia_de_datos done..
# Link:  http://wikipedia.org/wiki/Information_explosion done..
# Link:  https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/ done..
# Link:  http://wikipedia.org/wiki/Scientific_computing done..
# Link:  http://wikipedia.org/wiki/Committee_on_Data_for_Science_and_Technology done..
# Link:  https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/ done..
# Link:  https://cs.wikipedia.org/wiki/Data_science done..
# Link:  https://en.wikipedia.org/w/index.php?title=Data_science&oldid=1189437909 done..
# Link:  http://wikipedia.org/wiki/Andrew_Gelman done..
# Link:  https://www.researchgate.net/publication/354866394 done..
# Link:  http://wikipedia.org/wiki/Exploration done..
# Link:  http://wikipedia.org/wiki/Scientific_Data_(journal) done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=info done..
# Link:  http://wikipedia.org/wiki/Data_validation done..
# Link:  http://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License done..
# Link:  https://pl.wikipedia.org/wiki/Danologia done..
# Link:  https://www.wikidata.org/wiki/Special:EntityPage/Q2374463 done..
# Link:  http://wikipedia.org/wiki/Decision-making done..
# Link:  https://medriscoll.com/post/4740157098/the-three-sexy-skills-of-data-geeks done..
# Link:  http://wikipedia.org/wiki/Data_analyst done..
# Link:  http://wikipedia.org/wiki/Category:Articles_to_be_expanded_from_August_2023 done..
# Link:  https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/ done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=7 done..
# Link:  http://wikipedia.org/wiki/Data_recovery done..
# Link:  http://wikipedia.org/wiki/ISBN_(identifier) done..
# Link:  http://wikipedia.org/wiki/Academic_discipline done..
# Link:  https://ms.wikipedia.org/wiki/Sains_data done..
# Link:  http://wikipedia.org/wiki/PMID_(identifier) done..
# Link:  http://wikipedia.org/wiki/Buzzword done..
# Link:  http://wikipedia.org//foundation.wikimedia.org/wiki/Terms_of_Use done..
# Link:  https://www.springer.com/book/9784431702085 done..
# Link:  http://wikipedia.org/wiki/Statistical_analysis done..
# Link:  http://wikipedia.org//en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile done..
# Link:  http://wikipedia.org/wiki/Data_migration done..
# Link:  http://wikipedia.org/wiki/Data_cleansing done..
# Link:  http://wikipedia.org/wiki/Empirical_research done..
# Link:  http://wikipedia.org/wiki/New_York_City done..
# Link:  https://fi.wikipedia.org/wiki/Datatiede done..
# Link:  http://wikipedia.org/wiki/Unstructured_data done..
# Link:  https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/ done..
# Link:  http://wikipedia.org/wiki/Data_editing done..
# Link:  http://wikipedia.org/wiki/Data_integration done..
# Link:  http://wikipedia.org/wiki/OCLC_(identifier) done..
# Link:  https://static1.squarespace.com/static/5ff2adbe3fe4fe33db902812/t/6009dd9fa7bc363aa822d2c7/1611259312432/ISLR+Seventh+Printing.pdf done..
# Link:  https://es.wikipedia.org/wiki/Ciencia_de_datos done..
# Link:  http://wikipedia.org/w/index.php?title=Application_of_Statistics_and_Management&action=edit&redlink=1 done..
# Link:  http://wikipedia.org/wiki/Special:BookSources/9780123814791 done..
# Link:  http://wikipedia.org/wiki/Interdisciplinarity done..
# Link:  http://wikipedia.org/wiki/Data done..
# Link:  http://wikipedia.org/wiki/Data_retention done..
# Link:  http://wikipedia.org/wiki/Data_archaeology done..
# Link:  http://wikipedia.org/wiki/Statistics done..
# Link:  https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=4 done..
# Link:  http://wikipedia.org/wiki/Category:Computational_fields_of_study done..
# Link:  http://wikipedia.org/wiki/Extract,_load,_transform done..
# Link:  http://wikipedia.org/wiki/Problem-solving done..
# Link:  http://wikipedia.org/wiki/Data_processing done..
# Link:  http://wikipedia.org/wiki/National_Science_Board done..
# Link:  http://wikipedia.org/wiki/C._F._Jeff_Wu done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=history done..
# Link:  http://wikipedia.org/wiki/Communication done..
# Link:  http://wikipedia.org/wiki/New_York_Times done..
# Link:  https://wikimediafoundation.org/ done..
# Link:  https://books.google.com/books?id=oGs_AQAAIAAJ done..
# Link:  https://api.semanticscholar.org/CorpusID:114558008 done..
# Link:  http://wikipedia.org/wiki/Distributed_computing done..
# Link:  https://www.stat.purdue.edu/~wsc/ done..
# Link:  https://zu.wikipedia.org/wiki/INzululwazi_yeMininingo done..
# Link:  http://wikipedia.org/wiki/Special:BookSources/0-12-241770-4 done..
# Link:  http://wikipedia.org/wiki/Template_talk:Data done..
# Link:  http://wikipedia.org/wiki/Category:Articles_with_short_description done..
# Link:  http://wikipedia.org/wiki/Category:Computer_occupations done..
# Link:  http://wikipedia.org/wiki/Domain_knowledge done..
# Link:  http://wikipedia.org/wiki/Special:MyTalk done..
# Link:  http://wikipedia.org/wiki/Special:WhatLinksHere/Data_science done..
# Link:  http://wikipedia.org/wiki/File:Wiki_letter_w_cropped.svg done..
# Link:  https://www.worldcat.org/issn/0360-0300 done..
# Link:  https://www.mediawiki.org/ done..
# Link:  http://wikipedia.org/wiki/Portal:Current_events done..
# Link:  http://wikipedia.org/wiki/Data_engineering done..
# Link:  http://wikipedia.org/wiki/Machine_learning done..
# Link:  http://wikipedia.org/wiki/Category:CS1_errors:_periodical_ignored done..
# Link:  http://wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Data+science done..
# Link:  http://wikipedia.org/wiki/Data_curation done..
# Link:  http://wikipedia.org/wiki/Wikipedia:File_upload_wizard done..
# Link:  http://wikipedia.org/wiki/Category:All_articles_to_be_expanded done..
# Link:  http://wikipedia.org/wiki/Data_integrity done..
# Link:  http://wikipedia.org/wiki/Template:Data done..
# Link:  http://wikipedia.org/wiki/Domain_expertise done..
# Link:  https://eu.wikipedia.org/wiki/Datu_zientzia done..
# Link:  http://wikipedia.org/wiki/Talk:Data_science done..
# Link:  https://www.bostonglobe.com/business/2015/11/11/behind-scenes-sexiest-job-century/Kc1cvXIu31DfHhVmyRQeIJ/story.html done..
# Link:  http://wikipedia.org/wiki/Category:Data_analysis done..
# Link:  http://wikipedia.org/wiki/Harvard_Business_Review done..
# Link:  https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en done..
# Link:  http://wikipedia.org/wiki/Data_corruption done..
# Link:  https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century done..
# Link:  http://wikipedia.org/wiki/Wikipedia:Contents done..
# Link:  http://wikipedia.org/wiki/Thomas_H._Davenport done..
# Link:  http://wikipedia.org/wiki/Columbia_University done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=8 done..
# Link:  https://www.worldcat.org/issn/0036-8075 done..
# Link:  https://benfry.com/phd/dissertation/2.html done..
# Link:  http://wikipedia.org/wiki/Data_transformation done..
# Link:  http://wikipedia.org/wiki/Doi_(identifier) done..
# Link:  http://wikipedia.org/wiki/Data_visualization done..
# Link:  http://wikipedia.org/wiki/Interdisciplinary_field done..
# Link:  https://en.wikiversity.org/wiki/Data_science done..
# Link:  http://wikipedia.org/wiki/Data_pre-processing done..
# Link:  http://wikipedia.org/wiki/Data_scrubbing done..
# Link:  http://wikipedia.org/wiki/Special:BookSources/978-0-9825442-0-4 done..
# Link:  http://wikipedia.org/wiki/Help:CS1_errors#periodical_ignored done..
# Link:  http://wikipedia.org/wiki/Template:Cite_book done..
# Link:  https://www.oreilly.com/library/view/doing-data-science/9781449363871/ch01.html done..
# Link:  http://wikipedia.org/wiki/Data_cleaning done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=9 done..
# Link:  http://wikipedia.org/wiki/Information_technology done..
# Link:  http://wikipedia.org/wiki/Data_lineage done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=1 done..
# Link:  http://wikipedia.org/wiki/Journal_of_Computational_and_Graphical_Statistics done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&oldid=1189437909 done..
# Link:  https://no.wikipedia.org/wiki/Datavitenskap done..
# Link:  http://wikipedia.org/wiki/Peter_Naur done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&action=edit done..
# Link:  http://wikipedia.org/wiki/Nate_Silver done..
# Link:  http://wikipedia.org/wiki/Jeff_Hammerbacher done..
# Link:  http://wikipedia.org/wiki/Boston done..
# Link:  https://en.wikipedia.org/w/index.php?title=Data_science&action=edit&section= done..
# Link:  https://flowingdata.com/2009/06/04/rise-of-the-data-scientist/ done..
# Link:  http://wikipedia.org/wiki/Data_wrangling done..
# Link:  https://stats.wikimedia.org/#/en.wikipedia.org done..
# Link:  http://wikipedia.org/wiki/Women_in_Data done..
# Link:  http://wikipedia.org/wiki/Data_preservation done..
# Link:  http://wikipedia.org/wiki/Wikipedia:General_disclaimer done..
# Link:  http://wikipedia.org/wiki/Wikipedia:File_Upload_Wizard done..
# Link:  http://wikipedia.org/wiki/Data_extraction done..
# Link:  http://wikipedia.org/w/index.php?title=Data_science&printable=yes done..
# Link:  http://wikipedia.org/wiki/Turing_Award done..
# Link:  http://wikipedia.org/wiki/Special:BookSources/9784431702085 done..
# Link:  http://wikipedia.org/wiki/Wikipedia:Community_portal done..
# Link:  http://wikipedia.org/wiki/Special:RecentChanges done..
# Link:  https://www.statisticsviews.com/article/nate-silver-what-i-need-from-statisticians/ done..
# Link:  http://wikipedia.org/wiki/Data_preprocessing done..
# Link:  http://wikipedia.org/wiki/Data_science done..
# Link:  https://developer.wikimedia.org done..
# Link:  http://wikipedia.org/wiki/Extract,_transform,_load done..
# Link:  http://wikipedia.org/wiki/Knowledge_extraction done..
# Link:  http://wikipedia.org/wiki/ODSC done..
# Link:  http://wikipedia.org/wiki/Vasant_Dhar done..
# Link:  http://wikipedia.org/wiki/Computer_science done..
# Link:  http://wikipedia.org/wiki/Data_sonification done..
# Total Execution Time: 337.21 seconds

# %% [markdown]
# ### Step 7: Perform the page indexing in parallel and note the difference in performance.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
import multiprocessing

# %%
import concurrent.futures

def index_page_parallel(link):
    try:
        # Your existing index_page function logic here
        index_page(link)
    except Exception as e:
        pass

start_time_parallel = time.time()


with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(index_page_parallel, cleaned_links)

end_time_parallel = time.time()
execution_time_parallel = end_time_parallel - start_time_parallel

print(f"Total Execution Time (Parallel): {execution_time_parallel:.2f} seconds")
